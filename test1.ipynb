# %%
print(1)
# Out:
# 1

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.5.0

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.9.0

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.18.0
